# %% [markdown]
# - Tic Tac Taoe
#     - [X] __init__
#     - [X] get_random_first-player
#     - [X] fix_spot: mark board
#     - [X] has_player_won(self, player)
#     - [X] is_board_filled
#     - [X] swap_player_turn
#     - [X] show_board

# %%
import random


class TicTacToe:
    def __init__(self):
        self.board: list[str] = [" "] * 10 #list(map(str, range(10))) # 0th index is not used
        self.player_turn = "X"

    def get_random_first_player(self):
        return random.choice(["X","O"])

    def show_board(self):
        print("\n")
        print(self.board[1] + "|" + self.board[2] + "|" + self.board[3])
        print("-----")
        print(self.board[4] + "|" + self.board[5] + "|" + self.board[6])
        print("-----")
        print(self.board[7] + "|" + self.board[8] + "|" + self.board[9])
        print("\n")

    def swap_player_turn(self):
        self.player_turn = "X" if self.player_turn != "X" else "O"
        return self.player_turn
    
    def is_board_filled(self):
        return " " not in self.board[1:]

    def fix_spot(self, cell: int, player: str):
        self.board[cell] = player

    def has_player_won(self, player: str):
        win_combination = [
            [1,2,3], [4,5,6], [7,8,9],  # rows
            [1,4,7], [2,5,8], [3,6,9],  # columns
            [3,5,9], [3,5,7]            # diagonals
        ]

        for combination in win_combination:
            if all([self.board[cell] == player for cell in combination]):
                return True
        return False
    
    def validate_input(self, cell: int) -> bool:
        while (cell < 1) or (cell > 9):
            print("Input out of range Enter Valid cell numebr from 1 to 9: ")
            return False
        
        while self.board[cell] != " ":
            print("This cell have been chosen before, try another cell ")
            return False
        
        return True

    def start(self):
        self.show_board()
        print(f"Player {self.player_turn} turn")
        cell = int(input("Enter cell numebr from 1 to 9: "))
        while self.validate_input(cell) == False:
            cell = int(input("Enter cell numebr from 1 to 9: "))

        self.fix_spot(cell,self.player_turn)
        if self.has_player_won(self.player_turn):
            self.show_board()
            print(f"player {self.player_turn} won!")
            break

        
        if self.is_board_filled():
            print("Draw!")
            break




game = TicTacToe()

# %%
game.fix_spot(8,'O')

# %%
game.show_board()
# Out:
# X|O|
# -----
#  |O|
# -----
#  |O|

# %%
game.has_player_won('O')
# Out:
# False

# %%
game.player_turn
# Out:
# 'X'

# %%
game.swap_player_turn()
# Out:
# 'O'
