# %%
import sys

# %%
sys.path
# Out:
# ['/home/arzhang/miniconda3/envs/1-train/lib/python313.zip',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13/lib-dynload',
#  '',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13/site-packages']
