# %%
from input_validator import get_valid_input

# %%
get_valid_input("Enter a number between ",1,10)
# Out:
# invalid input. please enter a number between 1 and 10.
# Invalid input. Please enter a number.
# 2

# %%
import sys

# %%
sys.path
# Out:
# ['/home/arzhang/miniconda3/envs/1-train/lib/python313.zip',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13/lib-dynload',
#  '',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13/site-packages']

# %%
sys.path.insert(0,"/home/arzhang/projects/1-train/tmp-py-practice/py-practice/1-number-guesser/soluationB/src/utils")

# %%
sys.path
# Out:
# ['/home/arzhang/projects/1-train/tmp-py-practice/py-practice/1-number-guesser/soluationB/src/utils',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python313.zip',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13/lib-dynload',
#  '',
#  '/home/arzhang/miniconda3/envs/1-train/lib/python3.13/site-packages']
